# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy 
from scipy import stats
survey_df = pd.read_csv('CSCI_Fall_2024_survey-2.csv')
df.head(26)
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
survey_df["origin"] = np.where(survey_df["What state/country were you born in?"] == "St. Louis MO", "Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "Kansas, overland Park","kansas",
                               np.where(survey_df["What state/country were you born in?"] == "TEXAS","Texas",
                               np.where(survey_df["What state/country were you born in?"] == "india","India",
                               np.where(survey_df["What state/country were you born in?"] == "People's Republic of China","China",
                               np.where(survey_df["What state/country were you born in?"] == "United States Missouri","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "saint louis mo","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "saint louis, mo","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "Missouri","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "saint louis mo","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "Oklahoma","Oklahoma",
                               np.where(survey_df["What state/country were you born in?"] == "New Jersey","New jersey",
                               np.where(survey_df["What state/country were you born in?"] == "Kansas, Overland Park","Kansas",
                               np.where(survey_df["What state/country were you born in?"] == "Cameroon","Cameroon",
                               np.where(survey_df["What state/country were you born in?"] == "Kazakhstah","Kazakhstah",
                               np.where(survey_df["What state/country were you born in?"] == "I was born in Chandigarh, India!","India",
                               np.where(survey_df["What state/country were you born in?"] == "Saint Louis Missouri","Missouri",
                               np.where(survey_df["What state/country were you born in?"] == "frankfurt, Germany","Germany",
                               np.where(survey_df["What state/country were you born in?"] == "Missouri, USA","Missouri", 
                               np.where(survey_df["What state/country were you born in?"] == "Mexico","Mexico",
                               np.where(survey_df["What state/country were you born in?"] == "Wisconsin","Wisconsin",
                               np.where(survey_df["What state/country were you born in?"] == "Gerogia (the country not the state)","Gerogia",
                               np.where(survey_df["What state/country were you born in?"] == "st. louis, mo","Missouri",None)))))))))))))))))))))))
survey_df["origin"].value_counts()
#print(results)
# Out:
# origin
# Missouri      9
# India         2
# Mexico        1
# Wisconsin     1
# New jersey    1
# Kansas        1
# Oklahoma      1
# China         1
# Cameroon      1
# Texas         1
# Kazakhstah    1
# Name: count, dtype: int64

# %%
survey_df["origin"] = np.where(survey_df["What is your major?"] == "Computer Science","comp sci",
                               np.where(survey_df["What is your major?"] == "CS/Business","CS/Business",
                               np.where(survey_df["What is your major?"] == "Data Science","Data Science",
                               np.where(survey_df["What is your major?"] == "Buisness Economics","Buisness Economics",
                               np.where(survey_df["What is your major?"] == "computer science","comp sci",
                               np.where(survey_df["What is your major?"] == "cs/finance","cs/finance",
                               np.where(survey_df["What is your major?"] == "Computer Science; considering an additional major or a minor","comp sci",
                               np.where(survey_df["What is your major?"] == "comp sci","comp sci",
                               np.where(survey_df["What is your major?"] == "Biology w/ evolutionary bio minor","biology",
                               np.where(survey_df["What is your major?"] == "Computer Science, B.A. (I might switch to B.S digital ip law,eventually","comp sci",
                               np.where(survey_df["What is your major?"] == "TBD","TBD",
                               np.where(survey_df["What is your major?"] == "Economics", "Buisness Economics",None))))))))))))
survey_df["origin"].value_counts()
# Out:
# origin
# comp sci        13
# Data Science     3
# CS/Business      1
# biology          1
# TBD              1
# Name: count, dtype: int64

# %%
survey_df["origin"] = np.where(survey_df["How many pets and of which kind do you have?"] == "1, dog", "1 dog",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "0", "no pets",  
                        np.where(survey_df["How many pets and of which kind do you have?"] == "none","no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "N/A","no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "1 dog and 1 cat","1 dog and cat",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "2 cats, one dog","2 cats 1 dog",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "I have two dogs and they are both at home","2 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "1", "1 pet",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "no pets!", "no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "I have two dogs. They're bernedoodles.","2 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "2 dogs","2 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "2, dogs.","2 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "three dogs","3 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "No pets","no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "2 minature schnauzers", "2 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "None :( But I really want a cat!","no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "1 Cat; 6 Dogs (Over two households)","1 cat 6 dogs",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "had 8 dogs, not anymore","no pets",
                        np.where(survey_df["How many pets and of which kind do you have?"] == "2, Grumpy the exotic shorthair w heterchromia and my dog Furball is a rescue but he is just as cute ","2 cats and 1 dog",None)))))))))))))))))))
              
survey_df["origin"].value_counts()
# Out:
# origin
# no pets          12
# 2 dogs            5
# 1 dog and cat     1
# 2 cats 1 dog      1
# 1 pet             1
# 1 cat 6 dogs      1
# 3 dogs            1
# Name: count, dtype: int64

# %%
survey_df["What is your major?"].value_counts()
# Out:
# What is your major?
# Computer Science                                                                                                 10
# Data Science                                                                                                      3
# CS/Business                                                                                                       1
# Business Economics                                                                                                1
# computer science                                                                                                  1
# cs/ finance                                                                                                       1
# Computer Science; considering an additional major or a minor                                                      1
# comp sci                                                                                                          1
# ...

# %%
survey_df["How old are you?"].value_counts()
# Out:
# How old are you?
# 18    18
# 19     4
# 21     2
# 20     1
# 17     1
# Name: count, dtype: int64

# %%
survey_df["What is your favorite type of food?"].value_counts()
# Out:
# What is your favorite type of food?
# Italian             6
# Japanese            5
# Mexican             5
# American            3
# Indian              3
# Chinese             2
# all of the above    1
# korean              1
# Name: count, dtype: int64

# %%
y = np.array([6,5,5,3,3,2,1,1])
label = ["Italian", "Japanese", "mexican", "american","indian","chinese","all of the above","korean"]

plt.pie(y, labels = label)
plt.show()

# %% [markdown]
# # this pie chart shows that the people in my class like mexican, italian, and japanese food the most.

# %%
x = np.array(["17","18", "19", "20", "21"])
y = np.array([1, 18, 4, 2, 1])
plt.xlabel("age")
plt.ylabel("students")
plt.bar(x,y)
plt.show()

# %% [markdown]
# # this chart shows that most people in my class are 18

# %%
# this shows the number of cats and dogs that people in my class own
x = np.array([0,2,1,1,6,3,1])
y = np.array([0,0,1,2,1,0,0])
plt.xlabel("dog")
plt.ylabel("cat")
plt.scatter(x, y)
plt.show()

# %%
y = np.array([9,2,1,1,1,1,1,1,1,1,1,])
label = ["Missouri","China", "India", "Texas","mexico","Wisconsin","New Jersey","Kansas","Oklahoma","Cameroon","Kazakhstah"]
plt.pie(y, labels = label)
plt.show()
# this chart show the magoirty of wher epeople are from in our class

# %%
x = np.array(["ComputerScience","DataScience","CS/Business","BusinessEconomics","cs/finance","Biology","TBD","Economics"])
y = np.array([17,4,1,1,1,1,1,1])
plt.xlabel("major")
plt.ylabel("people in major")
plt.bar(x,y)
plt.show()

# %%
# the people in each major is what this graph describes
