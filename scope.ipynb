# %%
# local-only available to theoher code in its scope. a function, for example only has access to the names defined
#in that function or passed into it via arguments.
# enclosing-only existing for nested functions. inner nest can access to the names in outer nest.
# global- avalible to all your code and can be passed through modules, classes, etc
# built in- all names that are created by python when you run a script.

# %%
#constracter
#a class_sample_class:
    # defualt constuctor
    def __init__(self)
    self.var = 0
  
    # an instance method for printing
    def print_vars(self):
        print(self.var)

#create instance of class
obj = a_sampale_class()

#call instance method to get value for var

obj.print_vars()
# Out:
#   Cell In[7], line 4
#     def __init__(self)
#     ^
# IndentationError: unexpected indent

# %%
def __init__(self, one, two):
    self.first = one

def print_vars(self):
    print(self.first)
obj = a_sample_class(2,8)
obj.print_vars()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 def print_vars(self):
#       5     print(self.first)
# ----> 6 obj = a_sample_class(2,8)
#       7 obj.print_vars()
#
# NameError: name 'a_sample_class' is not defined

# %%
class_attr = 5
def __init__(self, one, two):
    self.first = one
    self.second = two
# object = is instance of classs
obj = a_sample_class(17,42)

#instance attribute as property of aoject
print(obj.first)

# class attribuite as property of object
print_vars(obj.class_attr)

#instance attribuite as property of object
print_vars(a_sample_class.first)

#class attribuite as property of class
Print(a_sample_class.attr)

# %% [markdown]
# #3 types of methodes
# class mmethpd
#  static method
# instance method

# %% [markdown]
# # Instance attibute and class attribute
# 2 scompes for attributes
#
# instance attribute = variable that belongs to a specific instance of instatiations
# Defined inside the constrocter (init). can access from the scope of an object (local)
#
# class attribute = type of variable that belongs to the class itself. similar to thativ attributes in java (not exact same). it is both a property of class And a propretty of the object. we can mutate a class class attribute to be an isntance attribute

# %%
help(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 help(obj)
#
# NameError: name 'obj' is not defined

# %%
#dir = directory of names in the current local scope
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__init__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'print_vars',
#  'quit']

# %%
#RUTURNING THE current module name space
# namespace =  mapping between objects and current names. these are defined names
# andf they also include informathin about objects each name refrences.
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '#constracter\n#a class_sample_class:\n# defualt constuctor\ndef __init__(self)\n    self.var=0\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sampale_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#   '#constracter\n#a class_sample_class:\n# defualt constuctor\ndef _init_(self)\n    self.var=0\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sampale_class()\n\n#call instance method to get value for var\nobj.print_vars()',
# ...

# %% [markdown]
# # instance, class and, static method

# %%
class Candy: 
    # variables that start with a single underscore are resurved for internal purpose
    def __init__(self, _brand, 
                _is_caramel=False,
                _is_chocolate=False,
                _is_vegan=False
                _has_nuts=False
                _type='chocolate',
                _calories=200):
            self.brand = _brand
            self.is_caramel = is_caramel
            self.is_chocolate = _is_chocolate
            self.is_vegan = _is_vegan
            self.has_nuts = _has_nuts
            self.calories = _calories
        self.type = type 
    # class method - used ot modify the stat of the class(for all instances)
    @classmethod
    def snicker(cls):
        return cls('Mars', _is_caramel=True , _has_nuts=True, type='snickers)'
    # instance method - can acces and modify both class and instance state
    # printint is accessing state
        def display(self):
            print(f'my favorite candy is {self.brand}, {self.type}')
    #static method - used for comparison or validation
    # commonly used in data for checking if data meets particular conditions
    # if you want to 
def calories(size,n):
    if size == 'regular'
elif size =='regular':
            calories

# %%
favorite_candy = Candy(_brand='Hersheys', _is_chocolate=True,
                      )
favorite_candy,display()

# %%
cand.calories('funsized',50)

# %% [markdown]
# # decorators
# is to exented behavior of a function without explicitly changing said function

# %%
def the_decorator(func):
    print("decorator is running")
    func()
    print("still running")

def oh_hi():
    print("Hello there!")

hello = the_decorator(oh_hi)
# Out:
# decorator is running
# Hello there!
# still running
